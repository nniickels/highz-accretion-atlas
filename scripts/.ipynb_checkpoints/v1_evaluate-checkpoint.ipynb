# %% [markdown]
# ## high-z-accretion-atlas v1
# Using functions defined in `src/models.py` and `src/scoring.py`, this code tests `v1_processed.csv` objects against a menu of different seed+growth models and scores feasibility. It also generates core plots for analysis.

# %%
# imports
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# paths
parent = r"C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas"
src_dir = parent + r"\src"
results_dir = parent + r"\results"
processed_data_dir = parent + r"\data\processed\v1_processed.csv"
requirements_table_path = results_dir + r'\v1_requirements_table.csv'
score_table_path = results_dir + r'\v1_model_scores.csv'
plot1_path = results_dir + r'\v1_mbh_mstar_vs_z.png'
plot2_path = results_dir + r'\v1_required_fedd_vs_z.png'
plot3_path = results_dir + r'\v1_feasibility_heatmap.png'
summary_path = results_dir + r'\v1_feasibility_summary.csv'

# import from src
sys.path.insert(0, src_dir)          

from models import (
    SEED_MODELS,
    apply_mbh_interpretation,
    apply_mstar_agn_contamination,
    evaluate_seed_model,
    required_average_fedd,
)
from scoring import score_model_table
from standardize_data import cosmic_time_gyr

# %%
# load processed data
df = pd.read_csv(processed_data_dir)
print(f'Loaded {len(df)} rows from {processed_data_dir}.')
df.head()
# Out:
# Loaded 23 rows from C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\data\processed\v1_processed.csv.
#             measurement_id    object_id    ra_deg   dec_deg  redshift  \
# 0  GS30148179_juodzbalis25  GS-30148179  53.14208 -27.77985     5.922
# 1  GS10013704_juodzbalis25  GS-10013704  53.12654 -27.81809     5.919
# 2    GS210600_juodzbalis25    GS-210600  53.16611 -27.77985     6.306
# 3    GS204851_juodzbalis25    GS-204851  53.13859 -27.79025     5.480
# 4    GS172975_juodzbalis25    GS-172975  53.08773 -27.87124     4.741
#
#    cosmic_time_gyr survey    object_class  log_mbh_msun_std  \
# 0         0.932484  JADES  broad-line-agn              7.12
# 1         0.933089  JADES  broad-line-agn              7.44
# 2         0.860092  JADES  broad-line-agn              7.41
# 3         1.029237  JADES  broad-line-agn              7.68
# 4         1.233465  JADES  broad-line-agn              7.25
#
#    log_mbh_err_plus_std  ...  log_mbh_mstar_ratio_err  edd_ratio_std  \
# 0                  0.34  ...                 0.674852          0.110
# 1                  0.31  ...                 0.951893          0.055
# 2                  0.33  ...                 0.695935          0.057
# 3                  0.32  ...                 0.327605          0.160
# 4                  0.32  ...                 0.349285          0.050
#
#    edd_ratio_err_std  mbh_interpretation_tag  \
# 0             0.0400     single-epoch-virial
# 1             0.0065     single-epoch-virial
# 2             0.0145     single-epoch-virial
# 3             0.0250     single-epoch-virial
# 4             0.0100     single-epoch-virial
#
#                mstar_interpretation_tag            lbol_interpretation_tag  \
# 0  host-sed-with-agn-contamination-risk  balmer-line-bolometric-correction
# 1  host-sed-with-agn-contamination-risk  balmer-line-bolometric-correction
# 2  host-sed-with-agn-contamination-risk  balmer-line-bolometric-correction
# 3  host-sed-with-agn-contamination-risk  balmer-line-bolometric-correction
# 4  host-sed-with-agn-contamination-risk  balmer-line-bolometric-correction
#
#    quality_flag  project_version                source_key  \
# 0        robust               v1  juodzbalis25_jades_blagn
# 1        robust               v1  juodzbalis25_jades_blagn
# 2        robust               v1  juodzbalis25_jades_blagn
# 3        robust               v1  juodzbalis25_jades_blagn
# 4        robust               v1  juodzbalis25_jades_blagn
#
#                                      notes
# 0  Robust sample; Mstar uses BEAGLE value.
# 1  Robust sample; Mstar uses BEAGLE value.
# 2  Robust sample; Mstar uses BEAGLE value.
# 3  Robust sample; Mstar uses BEAGLE value.
# 4  Robust sample; Mstar uses BEAGLE value.
#
# [5 rows x 28 columns]

# %% [markdown]
# Menu of interpretations and seed+growth models (also listed in `docs/model-menu.md`):

# %%
# define interpretation variants (v1 simple branch set)
interpretation_variants = {
    'baseline': {'mbh_delta_dex': 0.0, 'mstar_agn_fraction': 0.0},
    'mbh_minus_0p3dex': {'mbh_delta_dex': -0.3, 'mstar_agn_fraction': 0.0},
    'mbh_plus_0p3dex': {'mbh_delta_dex': 0.3, 'mstar_agn_fraction': 0.0},
    'mstar_agn_20pct': {'mbh_delta_dex': 0.0, 'mstar_agn_fraction': 0.2},
}

# define growth configurations
growth_configs = {
    'eddington_eps0p1': {'f_edd_avg': 1.0, 'epsilon': 0.1, 'merger_boost': 1.0},
    'subeddington_eps0p1': {'f_edd_avg': 0.3, 'epsilon': 0.1, 'merger_boost': 1.0},
    'supercritical_eps0p05': {'f_edd_avg': 2.0, 'epsilon': 0.05, 'merger_boost': 1.0},
    'merger_boost_x2': {'f_edd_avg': 1.0, 'epsilon': 0.1, 'merger_boost': 2.0},
}

# assume seed formation starts at z_seed = 30 for v1 timing budget.
t_seed_gyr = float(cosmic_time_gyr(np.array([30.0]))[0])
print(f'Seed-start cosmic time (z=30): {t_seed_gyr:.4f} Gyr')
# Out:
# Seed-start cosmic time (z=30): 0.0985 Gyr

# %%
rows = []

for _, obj in df.iterrows():
    delta_t = max(float(obj['cosmic_time_gyr']) - t_seed_gyr, 1e-6)

    for iv_name, iv in interpretation_variants.items():
        log_mbh = float(apply_mbh_interpretation(obj['log_mbh_msun_std'], iv['mbh_delta_dex']))
        log_mstar = float(apply_mstar_agn_contamination(obj['log_mstar_msun_std'], iv['mstar_agn_fraction']))

        for gc_name, gc in growth_configs.items():
            for seed_name, seed_model in SEED_MODELS.items():
                ev = evaluate_seed_model(
                    log_mbh_final=log_mbh,
                    delta_t_gyr=delta_t,
                    model_name=seed_name,
                    f_edd_avg=gc['f_edd_avg'],
                    epsilon=gc['epsilon'],
                    merger_boost=gc['merger_boost'],
                )

                # For required average f_Edd, use geometric-mid prior seed mass.
                log_seed_mid = 0.5 * (seed_model.log_mseed_min + seed_model.log_mseed_max)
                req_fedd = float(
                    required_average_fedd(
                        log_mseed=log_seed_mid,
                        log_mbh_final=log_mbh,
                        delta_t_gyr=delta_t,
                        epsilon=gc['epsilon'],
                        merger_boost=gc['merger_boost'],
                    )
                )

                rows.append({
                    'measurement_id': obj['measurement_id'],
                    'object_id': obj['object_id'],
                    'redshift': float(obj['redshift']),
                    'quality_flag': obj['quality_flag'],
                    'interpretation_variant': iv_name,
                    'growth_config': gc_name,
                    'seed_model': seed_name,
                    'delta_t_gyr': delta_t,
                    'log_mbh_eval': log_mbh,
                    'log_mstar_eval': log_mstar,
                    'log_mbh_mstar_ratio_eval': log_mbh - log_mstar,
                    'required_fedd': req_fedd,
                    **ev,
                })

eval_df = pd.DataFrame(rows)
print(f'Evaluation rows: {len(eval_df)}')
eval_df.head()
# Out:
# Evaluation rows: 1472
#             measurement_id    object_id  redshift quality_flag  \
# 0  GS30148179_juodzbalis25  GS-30148179     5.922       robust
# 1  GS30148179_juodzbalis25  GS-30148179     5.922       robust
# 2  GS30148179_juodzbalis25  GS-30148179     5.922       robust
# 3  GS30148179_juodzbalis25  GS-30148179     5.922       robust
# 4  GS30148179_juodzbalis25  GS-30148179     5.922       robust
#
#   interpretation_variant        growth_config            seed_model  \
# 0               baseline     eddington_eps0p1          light_popiii
# 1               baseline     eddington_eps0p1  intermediate_cluster
# 2               baseline     eddington_eps0p1            heavy_dcbh
# 3               baseline     eddington_eps0p1                   pbh
# 4               baseline  subeddington_eps0p1          light_popiii
#
#    delta_t_gyr  log_mbh_eval  log_mstar_eval  log_mbh_mstar_ratio_eval  \
# 0     0.833981          7.12            8.95                     -1.83
# 1     0.833981          7.12            8.95                     -1.83
# 2     0.833981          7.12            8.95                     -1.83
# 3     0.833981          7.12            8.95                     -1.83
# 4     0.833981          7.12            8.95                     -1.83
#
#    required_fedd            model_name  required_log_mseed  \
# 0       0.775829          light_popiii           -0.123868
# 1       0.499733  intermediate_cluster           -0.123868
# 2       0.292661            heavy_dcbh           -0.123868
# 3       0.430709                   pbh           -0.123868
# 4       0.775829          light_popiii            4.946840
#
#    model_log_mseed_min  model_log_mseed_max  is_feasible
# 0                  1.0                  2.0        False
# 1                  3.0                  4.0        False
# 2                  4.0                  6.0        False
# 3                  2.0                  6.0        False
# 4                  1.0                  2.0        False

# %%
scored_df = score_model_table(eval_df)

# Save full evaluation table + scored table
eval_df.to_csv(requirements_table_path, index=False)
scored_df.to_csv(score_table_path, index=False)

print(f'Saved requirements table: {requirements_table_path}')
print(f'Saved score table: {score_table_path}')

scored_df[['measurement_id', 'interpretation_variant', 'growth_config', 'seed_model', 'feasibility_score']].head()
# Out:
# Saved requirements table: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_requirements_table.csv
# Saved score table: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_model_scores.csv
#             measurement_id interpretation_variant        growth_config  \
# 0  GS30148179_juodzbalis25               baseline     eddington_eps0p1
# 1  GS30148179_juodzbalis25               baseline     eddington_eps0p1
# 2  GS30148179_juodzbalis25               baseline     eddington_eps0p1
# 3  GS30148179_juodzbalis25               baseline     eddington_eps0p1
# 4  GS30148179_juodzbalis25               baseline  subeddington_eps0p1
#
#              seed_model  feasibility_score
# 0          light_popiii                0.4
# 1  intermediate_cluster                0.4
# 2            heavy_dcbh                0.4
# 3                   pbh                0.4
# 4          light_popiii                0.4

# %%
# Core plot 1: MBH/M* vs z for the standardized catalogue
fig, ax = plt.subplots(figsize=(7, 4.5))
for flag, subset in df.groupby('quality_flag'):
    ax.scatter(
        subset['redshift'],
        subset['log_mbh_mstar_ratio'],
        label=flag,
        alpha=0.8,
    )
ax.set_xlabel('Redshift')
ax.set_ylabel(r'log$_{10}$(M$_{BH}$/M$_*$)')
ax.set_title('v1 catalogue: MBH/M* vs redshift')
ax.legend(title='quality_flag')
ax.grid(alpha=0.2)
fig.tight_layout()
fig.savefig(plot1_path, dpi=180)
plt.show()
print(f'Saved: {plot1_path}')
# Out:
# Saved: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_mbh_mstar_vs_z.png

# %%
# Core plot 2: required mean f_Edd vs z (baseline interpretation, eddington_eps0p1)
plot2_df = scored_df[
    (scored_df['interpretation_variant'] == 'baseline')
    & (scored_df['growth_config'] == 'eddington_eps0p1')
].copy()

fig, ax = plt.subplots(figsize=(8, 4.5))
for seed_name, subset in plot2_df.groupby('seed_model'):
    ax.scatter(subset['redshift'], subset['required_fedd'], label=seed_name, alpha=0.75)

ax.axhline(1.0, linestyle='--', linewidth=1.2, color='k', alpha=0.6, label='f_Edd = 1')
ax.set_xlabel('Redshift')
ax.set_ylabel('Required average f_Edd')
ax.set_title('Required average f_Edd vs redshift')
ax.set_yscale('log')
ax.grid(alpha=0.2)
ax.legend(fontsize=8)
fig.tight_layout()
fig.savefig(plot2_path, dpi=180)
plt.show()
print(f'Saved: {plot2_path}')
# Out:
# Saved: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_required_fedd_vs_z.png

# %%
# Core plot 3: feasibility heatmap (object x seed model), baseline/eddington only
heat_df = scored_df[
    (scored_df['interpretation_variant'] == 'baseline')
    & (scored_df['growth_config'] == 'eddington_eps0p1')
]

pivot = heat_df.pivot_table(
    index='object_id',
    columns='seed_model',
    values='feasibility_score',
    aggfunc='mean',
).sort_index()

fig, ax = plt.subplots(figsize=(7.5, max(4.0, 0.35 * len(pivot))))
im = ax.imshow(pivot.values, aspect='auto', vmin=0, vmax=1, cmap='viridis')
ax.set_xticks(np.arange(len(pivot.columns)))
ax.set_xticklabels(pivot.columns, rotation=30, ha='right')
ax.set_yticks(np.arange(len(pivot.index)))
ax.set_yticklabels(pivot.index)
ax.set_title('Feasibility score heatmap (baseline, eddington_eps0p1)')
cb = fig.colorbar(im, ax=ax)
cb.set_label('Feasibility score')
fig.tight_layout()
fig.savefig(plot3_path, dpi=180)
plt.show()
print(f'Saved: {plot3_path}')
# Out:
# Saved: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_feasibility_heatmap.png

# %%
# Compact summary table for quick inspection
summary = (
    scored_df
    .groupby(['interpretation_variant', 'growth_config', 'seed_model'], as_index=False)['feasibility_score']
    .agg(['mean', 'median', 'min', 'max'])
    .reset_index()
    .sort_values(['mean', 'median'], ascending=False)
)
summary.to_csv(summary_path, index=False)
print(f'Saved: {summary_path}')
summary.head(12)
# Out:
# Saved: C:\Users\nicol\OneDrive\coding\projects\Dayal\highz-accretion-atlas\results\v1_feasibility_summary.csv
#     index interpretation_variant        growth_config            seed_model  \
# 27     27       mbh_minus_0p3dex  subeddington_eps0p1                   pbh
# 11     11               baseline  subeddington_eps0p1                   pbh
# 59     59        mstar_agn_20pct  subeddington_eps0p1                   pbh
# 43     43        mbh_plus_0p3dex  subeddington_eps0p1                   pbh
# 8       8               baseline  subeddington_eps0p1            heavy_dcbh
# 56     56        mstar_agn_20pct  subeddington_eps0p1            heavy_dcbh
# 24     24       mbh_minus_0p3dex  subeddington_eps0p1            heavy_dcbh
# 40     40        mbh_plus_0p3dex  subeddington_eps0p1            heavy_dcbh
# 25     25       mbh_minus_0p3dex  subeddington_eps0p1  intermediate_cluster
# 9       9               baseline  subeddington_eps0p1  intermediate_cluster
# 57     57        mstar_agn_20pct  subeddington_eps0p1  intermediate_cluster
# 35     35        mbh_plus_0p3dex     eddington_eps0p1                   pbh
#
#         mean    median       min  max
# 27  0.976726  1.000000  0.464704  1.0
# 11  0.961318  1.000000  0.400000  1.0
# 59  0.961318  1.000000  0.400000  1.0
# 43  0.898110  1.000000  0.400000  1.0
# 8   0.891516  1.000000  0.400000  1.0
# 56  0.891516  1.000000  0.400000  1.0
# 24  0.852408  1.000000  0.400000  1.0
# 40  0.843961  1.000000  0.400000  1.0
# 25  0.609707  0.404244  0.400000  1.0
# 9   0.576677  0.400000  0.400000  1.0
# 57  0.576677  0.400000  0.400000  1.0
# 35  0.556522  0.400000  0.400000  1.0
